# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('Exercise_canada_per_capita_income.csv')
df2 = pd.read_csv('new_years.csv')
df2.head(3)
df2.shape
# Out:
# (14, 3)

# %%
plt.scatter(df.year,df['per capita income (US$)'], color='black', marker='+')
plt.xlabel('Year')
plt.ylabel('Per capita income $')
plt.plot(df2.new_year,reg.predict(df2[['new_year']]),color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 plt.xlabel('Year')
#       3 plt.ylabel('Per capita income $')
# ----> 4 plt.plot(df2.new_year,reg.predict(df2[['new_year']]),color='red')
#       5 plt.show()
#
# NameError: name 'reg' is not defined

# %%
x = df[['year']]
y = df['per capita income (US$)']

# %%
reg = linear_model.LinearRegression()
reg.fit(x.values,y)
reg.predict([[3000]])
# Out:
# array([853184.46781267])

# %%
plt.scatter(df.year,df['per capita income (US$)'], color='black', marker='+')
plt.xlabel('Year')
plt.ylabel('Per capita income $')
plt.plot(df.year,reg.predict(df[['year']]),color='lime')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
df2.head(3)

# %%
df2_price = reg.predict(df2)

# %%
df2['Prices'] = df2_price

# %%
df2.head(3)

# %%
df2.to_csv('new_years.csv')

# %%
df2
